# %%
from IPython.display import Image
Image("queue_1.png",width=800,height=500)

# %%
Image("queue_2.png",width=800,height=500)

# %%
Image("queue_3.png",width=800,height=500)

# %%
Image("queue_4.png",width=800,height=500)

# %%
Image("queue_5.png",width=800,height=500)

# %%
from IPython.display import Video
Video("queue.mov")
# Out:
# <video src="queue.mov" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Image("queue_6.png",width=800,height=500)

# %%
Image("queue_7.png",width=800,height=500)

# %%
class Solution:
    def reconstructQueue(self, people: List[List[int]]) -> List[List[int]]:
        people.sort(key = lambda x: (-x[0], x[1]))
        output = []
        for p in people:
            output.insert(p[1], p)
            
        return output
