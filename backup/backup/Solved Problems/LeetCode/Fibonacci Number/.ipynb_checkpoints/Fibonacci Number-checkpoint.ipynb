# %% [markdown]
# https://leetcode.com/problems/fibonacci-number/

# %%
from IPython.display import Image
Image("fib_1.png",width=700,height=500)

# %%
Image("fib_2.png",width=700,height=500)

# %%
Image("fib_3.png",width=700,height=500)

# %%
Image("fib_4.png",width=700,height=500)

# %%
Image("fib_5.png",width=700,height=500)

# %%
Image("fib_6.png",width=700,height=500)

# %%
Image("fib_7.png",width=700,height=500)

# %%
Image("fib_8.png",width=700,height=500)

# %%
Image("fib_9.png",width=700,height=500)

# %%
Image("fib_10.png",width=700,height=500)

# %%
Image("fib_11.png",width=700,height=500)

# %%
Image("fib_12.png",width=700,height=500)

# %%
Image("fib_13.png",width=700,height=500)

# %%
Image("fib_14.png",width=700,height=500)

# %%
Image("fib_15.png",width=700,height=500)

# %%
Image("fib_16.png",width=700,height=500)

# %%
Image("fib_17.png",width=700,height=500)

# %%
Image("fib_18.png",width=700,height=500)

# %%
Image("fib_19.png",width=700,height=500)

# %%
Image("fib_20.png",width=700,height=500)

# %%
Image("fib_21.png",width=700,height=500)
