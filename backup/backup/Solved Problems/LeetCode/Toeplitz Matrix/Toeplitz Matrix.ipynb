# %%
from IPython.display import Image
Image("toeplitz_1.png",width=700,height=500)

# %%
Image("toeplitz_2.png",width=700,height=500)

# %%
Image("toeplitz_3.png",width=700,height=500)

# %%
class Solution(object):
    def isToeplitzMatrix(self, matrix):
        groups = {}
        for r, row in enumerate(matrix):
            for c, val in enumerate(row):
                if r-c not in groups:
                    groups[r-c] = val
                elif groups[r-c] != val:
                    return False
        return True

# %%
Image("toeplitz_4.png",width=700,height=500)

# %%
Image("toeplitz_5.png",width=700,height=500)

# %%
class Solution:
    def isToeplitzMatrix(self, matrix: List[List[int]]) -> bool:
        
        n, m = len(matrix), len(matrix[0])
        
        for i in range(n-1):
            for j in range(m-1):
                if matrix[i][j] != matrix[i+1][j+1]:
                    return False
                
        return True

# %%
class Solution(object):
    def isToeplitzMatrix(self, matrix):
        return all(r == 0 or c == 0 or matrix[r-1][c-1] == val
                   for r, row in enumerate(matrix)
                   for c, val in enumerate(row))

# %%
class Solution {
public:
    bool isToeplitzMatrix(vector<vector<int>>& matrix) {
        
        for(int i = 0; i < matrix.size() - 1; i++) {
            for(int j = 0; j < matrix[0].size() - 1; j++) {
                
                if(matrix[i][j] != matrix[i+1][j+1]) {
                    return false;
                }
                
            }
        }
        
        return true;
    }
};

# %%
Image("toeplitz_6.png",width=700,height=500)
