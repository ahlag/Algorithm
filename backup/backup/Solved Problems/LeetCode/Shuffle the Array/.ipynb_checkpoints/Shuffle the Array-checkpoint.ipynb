# %%
from IPython.display import Image, Video
Image("array_1.png",width=500,height=500)

# %%
class Solution:
    def shuffle(self, nums, n):

        arr = []
        for i in range(n):
            arr.append(nums[i])
            arr.append(nums[i + n])
        
        return arr
