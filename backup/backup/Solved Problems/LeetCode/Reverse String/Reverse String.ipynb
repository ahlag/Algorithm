# %%
from IPython.display import Image
Image("invert_1.png",width=700,height=500)

# %%
Image("invert_2.png",width=700,height=500)

# %%
Image("invert_3.png",width=700,height=500)

# %%
Image("invert_4.png",width=700,height=500)

# %%
Image("invert_5.png",width=700,height=500)

# %%
Image("invert_6.png",width=700,height=500)

# %%
Image("invert_7.png",width=700,height=500)

# %%
class Solution:
    def reverseString(self, s: List[str]) -> None:
        """
        Do not return anything, modify s in-place instead.
        """
        left = 0
        right = len(s) - 1
        while left <= right:
            s[left], s[right] = s[right], s[left]
            left += 1
            right -= 1
            
        return s
