# %% [markdown]
# https://leetcode.com/problems/nested-list-weight-sum/

# %%
from IPython.display import Image, Video
Image("weight_1.png",width=700,height=500)

# %%
Image("weight_2.png",width=700,height=500)

# %%
Image("weight_3.png",width=700,height=500)

# %%
Image("weight_4.png",width=700,height=500)

# %%
def depthSum(self, nestedList):
    """
    :type nestedList: List[NestedInteger]
    :rtype: int
    """
    def dfs(nestedList, depth):
        total = 0
        for element in nestedList:
            if element.isInteger():
                total += (element.getInteger() * depth)
            else:
                total += dfs(element.getList(), depth + 1)

        return total
    
    return dfs(nestedList, 1)

# %%
class Solution:
    def depthSum(self, nestedList) -> int:
        
        if not nestedList: return 0
        
        total = 0
        stack = [(l, 1) for l in nestedList]
        
        while stack:
            l, index = stack.pop()
            
            value = l.getInteger()
            
            if value is not None:
                total += value * index
            else:
                for item in l.getList():
                    stack.append((item, index + 1))
        
        return total
