# %%
from IPython.display import Image
Image("dest_1.png",width=900,height=500)

# %%
Image("dest_2.png",width=900,height=500)

# %% [markdown]
# Algorithm:
# Unzip cities to fm and to and return the unque element in the "set difference".
#
# Implementation (time complexity O(N) & space complexity O(N))

# %%
def destCity(paths):
    fm, to = zip(*paths)
    return (set(to) - set(fm)).pop()

# %% [markdown]
# https://www.geeksforgeeks.org/python-set-difference/

# %%
Image("dest_3.png",width=900,height=500)

# %% [markdown]
# set A = {10, 20, 30, 40, 80}
# set B = {100, 30, 80, 40, 60}
#
# set A - set B = {10, 20}
# set B - set A = {100, 60}
#
# Explanation: A - B is equal to the elements present in A but not in B
#              B - A is equal to the elements present in B but not in A

# %%
Image("dest_4.png",width=900,height=500)

# %%
Image("dest_5.png",width=900,height=500)

# %%
Image("dest_6.png",width=900,height=500)

# %%
def destCity(self, paths) -> str:
        cityFrequency = dict()
        for cities in paths:
            if cities[0] in cityFrequency:
                cityFrequency[cities[0]] += 1
            else:
                cityFrequency[cities[0]] = 1
            
            if cities[1] in cityFrequency:
                cityFrequency[cities[1]] += 1
            else:
                cityFrequency[cities[1]] = 1
        
        
        for cities in paths:
            if cityFrequency[cities[1]] == 1:
                return cities[1]
