# %%
from IPython.display import Image, Video
Image("length_1.png",width=900,height=500)

# %%
Image("length_2.png",width=700,height=500)

# %%
Image("length_3.png",width=700,height=500)

# %%
## personal
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        word_list = s.split()
        if not word_list:
            return 0
        else:
            return len(word_list[-1])

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        # trim the trailing spaces
        p = len(s) - 1
        while p >= 0 and s[p] == ' ':
            p -= 1

        # compute the length of last word
        length = 0
        while p >= 0 and s[p] != ' ':
            p -= 1
            length += 1
        return length

# %%
Image("length_4.png",width=700,height=500)

# %%
Video("length.mov",width=700,height=300)
# Out:
# <video src="length.mov" controls  width="700"  height="300">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        p, length = len(s), 0

        while p > 0:
            p -= 1
            # we're in the middle of the last word
            if s[p] != ' ':
                length += 1
            # here is the end of last word
            elif length > 0:
                return length

        return length

# %%
Image("length_5.png",width=700,height=500)

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        return 0 if not s or s.isspace() else len(s.split()[-1])

# %%
Image("length_7.png",width=700,height=500)
