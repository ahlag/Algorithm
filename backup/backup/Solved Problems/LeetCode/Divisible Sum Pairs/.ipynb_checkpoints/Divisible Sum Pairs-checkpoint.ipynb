# %%
from IPython.display import Image
Image("div_1.png",width=700,height=500)

# %%
Image("div_2.png",width=700,height=500)

# %%
Image("div_3.png",width=700,height=500)

# %% [markdown]
# ## Brute Force O(n^2)

# %%
def divisibleSumPairs(n, k, ar):
    cnt = 0
    for i in range(n-1):
        for j in range(i+1, n):
            if (ar[i] + ar[j]) % k == 0:
                cnt += 1

# %% [markdown]
# https://www.hackerrank.com/challenges/divisible-sum-pairs/forum/comments/225528
#
# https://www.hackerrank.com/challenges/divisible-sum-pairs/forum
#
# https://www.hackerrank.com/challenges/divisible-sum-pairs/forum/comments/264595
#
# https://github.com/RodneyShag/HackerRank_solutions
