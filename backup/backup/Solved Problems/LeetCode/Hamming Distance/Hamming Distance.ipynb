# %%
from IPython.display import Image
Image("hamming_1.png",width=900,height=500)

# %%
Image("hamming_2.png",width=900,height=500)

# %%
Image("hamming_3.png",width=900,height=500)

# %%
Image("hamming_4.png",width=900,height=500)

# %%
Image("hamming_5.png",width=900,height=500)

# %%
Image("hamming_6.png",width=900,height=500)

# %%
Image("hamming_7.png",width=900,height=500)

# %%
Image("hamming_8.png",width=900,height=500)

# %%
Image("hamming_9.png",width=900,height=500)
