# %%
from IPython.display import Image
Image("bin_1.png",width=700,height=500)

# %%
Image("bin_2.png",width=700,height=500)

# %%
n = int(input())

if n < 2:
    print(n % 2)
else:
    binary = ''
    rem = n
    while rem != 0:
        binary += str(rem % 2)
        rem = rem // 2
    print(max([len(i) for i in binary.split('0')]))
# Out:
#  5
# 1

# %%
n = int(input())

if n < 2:
    print(n % 2)
else:
    binary = ''
    rem = n
    while rem != 0:
        binary += str(rem % 2)
        rem = rem // 2
    print(max([len(i) for i in binary.split('0')]))
# Out:
#  13
# 2

# %%
n = int(input())
s = str("{0:b}".format(n))
ls = s.split('0')
print(len(max(ls)))
# Out:
#  5
# 1
