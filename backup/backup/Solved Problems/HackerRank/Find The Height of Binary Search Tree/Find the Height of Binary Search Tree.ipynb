# %%
from IPython.display import Image
Image("height_1.png",width=700,height=500)

# %%
Image("height_2.png",width=700,height=500)

# %%
Image("height_3.png",width=300,height=500)

# %%
Image("height_4.png",width=700,height=500)

# %%
def getHeight(self,root):
        #Write your code here
        if root == None:
            return -1
        l = self.getHeight(root.left)
        r = self.getHeight(root.right)
        if l >= r:
            return l + 1
        else:
            return r + 1

# %%
Image("height_5.png",width=700,height=500)
