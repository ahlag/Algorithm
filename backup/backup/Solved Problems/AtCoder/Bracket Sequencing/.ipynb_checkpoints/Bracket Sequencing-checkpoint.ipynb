# %% [markdown]
# https://atcoder.jp/contests/abc167/tasks/abc167_f

# %%
from IPython.display import Image
Image("bracket_1.png",width=900,height=500)

# %%
Image("bracket_2.png",width=900,height=500)

# %%
Image("bracket_3.png",width=900,height=500)
