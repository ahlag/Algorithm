# %% [markdown]
# https://atcoder.jp/contests/abc157/tasks/abc157_c

# %%
from IPython.display import Image
Image("guess_1.png",width=700,height=500)

# %%
Image("guess_2.png",width=700,height=500)

# %%
Image("guess_3.png",width=700,height=500)

# %%
Image("guess_4.png",width=700,height=500)

# %%
Image("guess_5.png",width=700,height=500)
