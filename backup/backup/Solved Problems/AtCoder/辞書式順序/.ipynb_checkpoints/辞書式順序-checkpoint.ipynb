# %%
from IPython.display import Image
Image("dic_1.png",width=900,height=500)

# %%
Image("dic_2.png",width=900,height=500)

# %%
Image("dic_3.png",width=900,height=500)

# %%
print('a' if len(input()) != 1 else -1)
# Out:
#  aaaa
# a
