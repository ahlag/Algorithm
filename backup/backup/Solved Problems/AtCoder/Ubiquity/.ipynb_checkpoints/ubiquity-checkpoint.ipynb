# %% [markdown]
# https://atcoder.jp/contests/abc178/tasks/abc178_c

# %%
from IPython.display import Image
Image("ubiquity_1.png",width=700,height=500)

# %%
Image("ubiquity_2.png",width=700,height=500)

# %%
Image("explanation_1.png",width=700,height=500)

# %%
Image("explanation_2.png",width=700,height=500)

# %%
n = int(input())

MOD = 10 ** 9 + 7
ans = pow(10, n, MOD) - 2 * pow(9, n, MOD) + pow(8, n, MOD)
ans %= MOD
print(int(ans))
# Out:
#  2
# 2

# %%
Image("explanation_3.png",width=800,height=500)
