# %%
from IPython.display import Image
Image("gift_1.png",width=700,height=500)

# %%
Image("gift_2.png",width=700,height=500)

# %%
Image("gift_3.png",width=700,height=500)

# %%
x, y = map(int, input().split())

ans = 0

while x <= y:
    
    x *= 2
    ans += 1
    
print(ans)
# Out:
#  314159265 358979323846264338
# 31

# %% [markdown]
# https://kimiyuki.net/writeup/algo/atcoder/arc_088_c/

# %%
Image("gift_4.png",width=700,height=500)

# %% [markdown]
# https://murnana.hatenablog.com/entry/2017/12/28/190000

# %%
Image("gift_5.png",width=700,height=500)

# %%
Image("gift_6.png",width=700,height=500)

# %% [markdown]
# https://pitsbuffersolution.com/compro/atcoder/arc088c.php
