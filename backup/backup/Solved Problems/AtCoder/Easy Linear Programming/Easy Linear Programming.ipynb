# %%
from IPython.display import Image
Image("linear_1.png",width=900,height=500)

# %%
Image("linear_2.png",width=900,height=500)

# %%
A, B, C, K = map(int,input().split())

if K <= A:
    print(A)
elif K <= A+B:
    print(A)
else:
    print(A+(K-(A+B))*(-1))
# Out:
#  1 2 3 4
# 0

# %%
A, B, C, K = map(int,input().split())

if K <= A:
    print(A)
elif K <= A+B:
    print(A)
else:
    print(A+(K-(A+B))*(-1))
# Out:
#  2 1 1 3
# 2

# %%
A, B, C, K = map(int,input().split())

if K <= A:
    print(A)
elif K <= A+B:
    print(A)
else:
    print(A+(K-(A+B))*(-1))
# Out:
#  2000000000 0 0 2000000000
# 2000000000
