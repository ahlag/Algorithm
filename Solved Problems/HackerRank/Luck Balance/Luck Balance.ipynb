# %%
from IPython.display import Image
Image("luck_1.png",width=700,height=500)

# %%
Image("luck_2.png",width=700,height=500)

# %%
Image("luck_3.png",width=700,height=500)

# %%
n, k = map(int,input().split())
# Out:
#  6 3

# %%
res = 0
imp_contests = []
for i in range(n):
    lk,im = map(int,input().split())
    if im == 0:
        res += lk
    else:
        imp_contests.append(lk)
imp_contests.sort(reverse=True)
# Out:
#  5 1
#  2 1
#  1 1
#  8 1
#  10 0
#  5 0

# %%
imp_contests
# Out:
# [8, 5, 2, 1]

# %%
res += sum(imp_contests[:min(k,n)])

# %%
res
# Out:
# 30

# %%
res -= sum(imp_contests[k:])

# %%
res
# Out:
# 29

# %%
n, k = map(int, input().split())

# I can definitely lose all of the unimportant contests
# and I have to lose exactly k important contests
res = 0
imp_contest = []

for i in range(n):
    a, b = map(int, input().split())
    if b == 0:
        res += a
    else:
        imp_contest.append(a)
imp_contest.sort(reverse=True)

# Losing only k contests
res += sum(imp_contest[:min(k, len(imp_contest))])

# winning the remaining contests
res -= sum(imp_contest[k:])
print(res)
# Out:
#  6 3
#  5 1
#  2 1
#  1 1
#  8 1
#  10 0
#  5 0
# 29
