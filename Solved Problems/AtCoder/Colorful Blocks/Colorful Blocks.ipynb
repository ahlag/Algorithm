# %% [markdown]
# https://atcoder.jp/contests/abc167/tasks/abc167_e

# %%
from IPython.display import Image
Image("colorful_1.png",width=900,height=500)

# %%
Image("colorful_2.png",width=900,height=500)
