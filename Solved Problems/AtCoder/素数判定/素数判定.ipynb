# %%
from IPython.display import Image
Image("prime_1.png",width=600,height=500)

# %%
Image("prime_2.png",width=600,height=500)

# %%
n = int(input())

for i in range(2, int(n**0.5)+1):
    if n % i == 0:
        print("No")
        break

print("Yes")
# Out:
#  17
# Yes
