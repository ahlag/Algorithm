# %%
from IPython.display import Image
Image("island_1.png",width=700,height=500)

# %%
Image("island_2.png",width=700,height=500)

# %%
Image("island_3.png",width=700,height=500)

# %%
Image("island_4.png",width=700,height=500)

# %%
Image("island_5.png",width=700,height=500)

# %%
n = int(input())
people = list(map(int, input().split()))
total_people = sum(people)

if total_people % n != 0:
    print(-1)
    exit()

avg = total_people / n

subtotal = 0
islands = 0
res = 0
for i in range(n):

    subtotal += people[i] 
    islands += 1
    moving_avg = subtotal / islands 
    if moving_avg == avg:
        res += islands - 1
        subtotal = 0
        islands = 0
        
print(res)

# %% [markdown]
# https://satoooh.com/entry/3984/

# %%
Image("island_6.png",width=700,height=500)

# %%
N = int(input())
*a, = map(int, input().split())

if sum(a) % N != 0:
    print(-1)
    exit()

n = sum(a) // N
ans = 0
for i in range(N - 1):
    if sum(a[: i + 1]) != n * (i + 1):
        ans += 1
print(ans)
