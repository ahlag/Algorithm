# %%
from IPython.display import Image
Image("crane_1.png",width=800,height=500)

# %%
Image("crane_2.png",width=800,height=500)

# %%
X, Y = map(int, input().split())

for i in range(X+1):
    c = X - i
    if Y == i * 2 + c * 4:
        print('Yes')
        exit()
        
print('No')
