# %%
from IPython.display import Image
Image("abc_swap_1.png",width=800,height=500)

# %%
Image("abc_swap_2.png",width=800,height=500)

# %%
def swap(x,y,z):
  x, y = y, x
  x, z = z, x
  
  print('%d %d %d' % (x,y,z))
  
val = list(input().split())
x, y, z = [ int(x) for x in val ]
swap(x,y,z)
# Out:
#  1 2 3
# 3 1 2

# %%
a = list(map(int,input().split()))
a[0],a[1],a[2] = a[2], a[0], a[1]
print(*a)
# Out:
# 1 2 3
# 3 1 2
