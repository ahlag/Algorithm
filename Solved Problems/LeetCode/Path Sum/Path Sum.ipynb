# %%
from IPython.display import Image, Video
Image("path_1.png",width=700,height=500)

# %%
Image("path_2.png",width=700,height=500)

# %%
Image("path_3.png",width=700,height=500)

# %%
Image("path_4.png",width=700,height=500)

# %%
Image("path_5.png",width=700,height=500)

# %%
Video("path.mov",width=700,height=400)
# Out:
# <video src="path.mov" controls  width="700"  height="400">
#       Your browser does not support the <code>video</code> element.
#     </video>
