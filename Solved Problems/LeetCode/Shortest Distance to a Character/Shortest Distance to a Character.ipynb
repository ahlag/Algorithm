# %%
from IPython.display import Image, Video
Image("shortest_1.png",width=700,height=500)

# %%
Image("shortest_2.png",width=700,height=500)

# %%
class Solution:
    def shortestToChar(self, S: str, C: str):
        
        prev = -sys.maxsize
        ans = []
        for i, x in enumerate(S):
            if x == C:
                prev = i
            ans.append(i - prev)
            
        prev = float('inf')
        for i in range(len(S)-1,-1,-1):
            if S[i] == C:
                prev = i
            ans[i] = min(ans[i], prev - i)
            
        return ans

# %%
Image("shortest_3.png",width=700,height=500)
