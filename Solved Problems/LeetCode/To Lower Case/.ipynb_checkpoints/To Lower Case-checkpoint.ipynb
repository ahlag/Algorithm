# %%
from IPython.display import Image, Video
Image("to_lower_1.png",width=600,height=500)

# %%
Image("to_lower_2.png",width=600,height=500)

# %%
Image("to_lower_3.png",width=600,height=500)

# %%
class Solution:
    def toLowerCase(self, str: str) -> str:
        return str.lower()

# %%
Image("to_lower_4.png",width=600,height=500)

# %%
class Solution:
    def toLowerCase(self, word: str) -> str:
                
        upper = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
        lower = "abcdefghijklmnopqrstuvwxyz"
        d = dict(zip(upper, lower))
        
        arr = ''
        for i in range(len(word)):
            
            if word[i] in d:
                print(word[i])
                arr += d[word[i]]
            else:
                arr += word[i]
                
        return arr

# %%
Image("to_lower_5.png",width=600,height=500)

# %%
Image("to_lower_6.png",width=600,height=500)

# %%
Image("to_lower_7.png",width=600,height=500)

# %%
Video("to_lower.mov",width=600,height=300)
# Out:
# <video src="to_lower.mov" controls  width="600"  height="300">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
class Solution:
    def toLowerCase(self, str: str) -> str: 
        is_upper = lambda x : 'A' <= x <= 'Z'
        to_lower = lambda x : chr(ord(x) | 32)
        
        return ''.join([to_lower(x) if is_upper(x) else x for x in str])
