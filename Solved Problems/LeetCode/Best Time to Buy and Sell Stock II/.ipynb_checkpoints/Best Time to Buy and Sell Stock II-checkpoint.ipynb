# %%
from IPython.display import Image, Video
Image("stock_1.png",width=700,height=500)

# %%
Image("stock_2.png",width=700,height=500)

# %% [markdown]
# https://www.geeksforgeeks.org/stock-buy-sell/

# %%
class Solution:
    def maxProfit(self, prices) -> int:
    
        def helper(price, start, end):
         
            # If the stocks can't be bought
            if end <= start:
                return 0
         
            # Initialise the profit
            profit = 0
         
            # The day at which the stock
            # must be bought
            for i in range(start, end):
         
                # The day at which the
                # stock must be sold
                for j in range(i+1, end+1):
         
                    # If buying the stock at ith day and
                    # selling it at jth day is profitable
                    if price[j] > price[i]:
                         
                        # Update the current profit
                        curr_profit = price[j] - price[i] +\
                                    helper(price, j + 1, end)
         
                        # Update the maximum profit so far
                        profit = max(profit, curr_profit)
         
            return profit

        return helper(prices, 0, len(prices) - 1)

# %%
Image("stock_3.png",width=700,height=500)

# %%
Image("stock_4.png",width=700,height=500)

# %%
class Solution:
    def maxProfit(self, prices) -> int:
        
        i, n = 0, len(prices)
        max_profit = 0
        while i < n - 1:
            while i < n - 1 and prices[i] >= prices[i+1]:
                i += 1            
            valley = prices[i]

            while i < n - 1 and prices[i] <= prices[i+1]:
                i += 1
            peak = prices[i]
            max_profit += peak - valley
            
        return max_profit

# %%
Image("stock_5.png",width=700,height=500)

# %%
Image("stock_6.png",width=700,height=500)

# %%
class Solution:
    def maxProfit(self, prices) -> int:
        
        n = len(prices)
        max_profit = 0
        for i in range(1,n):
            if prices[i-1] < prices[i]:
                max_profit += prices[i] - prices[i-1]
        
        return max_profit

# %%
Image("stock_7.png",width=700,height=500)

# %% [markdown]
# ## DP
# <a>https://leetcode.com/problems/best-time-to-buy-and-sell-stock-ii/discuss/803206/Python-O(n)-by-DP-w-Visualization</a>

# %%
Image("stock_8.png",width=700,height=500)

# %%
class Solution:
    def maxProfit(self, prices) -> int:
        
        # It is impossible to sell stock on first day, set -infinity as initial value for cur_hold
        cur_hold, cur_not_hold = -float('inf'), 0
        
        for stock_price in prices:
            
            prev_hold, prev_not_hold = cur_hold, cur_not_hold
            
            # either keep hold, or buy in stock today at stock price
            cur_hold = max( prev_hold, prev_not_hold - stock_price )

            # either keep not-hold, or sell out stock today at stock price
            cur_not_hold = max( prev_not_hold, prev_hold + stock_price )
            
        # maximum profit must be in not-hold state
        return cur_not_hold if prices else 0

# %%
Image("stock_9.png",width=700,height=500)

# %%
Image("stock_10.png",width=700,height=500)
