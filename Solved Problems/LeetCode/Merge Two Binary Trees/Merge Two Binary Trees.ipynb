# %%
from IPython.display import Image
Image("merge_1.png",width=700,height=500)

# %%
Image("merge_2.png",width=700,height=500)

# %%
Image("merge_3.png",width=700,height=500)

# %%
Image("merge_4.png",width=700,height=500)

# %%
# Recursive
def mergeTrees(t1: TreeNode, t2: TreeNode) -> TreeNode:
    
    if t1 is None:
        return t2
    
    if t2 is None:
        return t1
    
    t1.val += t2.val
    t1.left = self.mergeTrees(t1.left,t2.left)
    t1.right = self.mergeTrees(t1.right, t2.right)
    
    return t1

# %%
Image("merge_5.png",width=700,height=500)

# %%
Image("merge_6.png",width=700,height=500)

# %%
def mergeTrees(self, t1, t2):
    """
    :type t1: TreeNode
    :type t2: TreeNode
    :rtype: TreeNode
    """
    if t1 == None:
        return t2
    stack = []
    stack = [[t1,t2]]
    while stack:
        cur = stack.pop()
        if cur[0] == None or cur[1] == None:
            continue
        cur[0].val += cur[1].val
        if cur[0].left == None:
            cur[0].left = cur[1].left
        else:
            stack.append([cur[0].left,cur[1].left])
        if cur[0].right == None:
            cur[0].right = cur[1].right
        else:
            stack.append([cur[0].right,cur[1].right])
    return t1
