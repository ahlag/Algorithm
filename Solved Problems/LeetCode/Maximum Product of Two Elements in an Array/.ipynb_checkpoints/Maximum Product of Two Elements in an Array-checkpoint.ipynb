# %%
from IPython.display import Image, Video
Image("sorted_1.png",width=700,height=500)

# %% [markdown]
# ## Personal solution (Using Sort)

# %%
class Solution:
    def maxProduct(self, nums) -> int:
        
        sorted_list = sorted(nums)
        
        return ((sorted_list[-1] -1) * (sorted_list[-2] - 1))

# %% [markdown]
# ## Linear Scan

# %%
def maxProduct(self, nums) -> int:
        no1 = max(nums)
        nums.remove(no1)
        no2 = max(nums)
        return (no1 - 1) * (no2 - 1)

# %%
Image("sorted_2.png",width=700,height=500)

# %%
class Solution(object):
    def maxProduct(self, nums):

        first, second = 0, 0
        
        for number in nums:
            
            if number > first:
                # update first largest and second largest
                first, second = number, first
                
            else:
                # update second largest
                second = max( number, second)
        
        return (first - 1) * (second - 1)
