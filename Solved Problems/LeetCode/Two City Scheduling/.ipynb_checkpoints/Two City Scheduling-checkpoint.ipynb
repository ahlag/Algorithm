# %%
from IPython.display import Image
Image("greedy_1.png",width=800,height=500)

# %%
Image("greedy_2.png",width=800,height=500)

# %%
Image("greedy_3.png",width=800,height=500)

# %%
Image("greedy_4.png",width=800,height=500)
