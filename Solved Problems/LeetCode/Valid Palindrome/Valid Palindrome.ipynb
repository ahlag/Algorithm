# %%
from IPython.display import Image, Video
Image("valid_1.png",width=700,height=500)

# %%
Image("valid_2.png",width=700,height=500)

# %%
import re
class Solution(object):
    def isPalindrome(self, s):
        """
        :type s: str
        :rtype: bool
        """
        word = "".join(re.findall("[a-zA-Z0-9]+", s))
        return True if word.lower() == word[::-1].lower() else False

# %%
Image("valid_3.png",width=700,height=500)

# %%
Image("valid_4.png",width=700,height=500)

# %%
Video("valid.mov",width=700,height=500)
# Out:
# <video src="valid.mov" controls  width="700"  height="500">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Image("valid_5.png",width=700,height=500)

# %%
class Solution(object):
    def isPalindrome(self, s):
        """
        :type s: str
        :rtype: bool
        """
        i, j = 0, len(s) - 1
        
        while i < j:
            
            while i < j and not s[i].isalnum():
                i += 1
            while i < j and not s[j].isalnum():
                j -= 1
        
            if i < j and s[i].lower() != s[j].lower():
                return False
            
            i += 1
            j -= 1
            
        return True

# %%
Image("valid_6.png",width=700,height=500)
