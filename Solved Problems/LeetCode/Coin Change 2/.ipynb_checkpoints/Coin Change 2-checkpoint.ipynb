# %%
from IPython.display import Image
Image("coin_1.png",width=800,height=500)

# %%
Image("coin_2.png",width=800,height=500)

# %%
Image("coin_3.png",width=800,height=500)

# %%
Image("coin_4.png",width=800,height=500)

# %%
Image("coin_5.png",width=800,height=500)

# %%
Image("coin_6.png",width=800,height=500)

# %%
Image("coin_7.png",width=800,height=500)

# %%
Image("coin_8.png",width=800,height=500)

# %%
Image("coin_9.png",width=800,height=500)

# %%
Image("coin_10.png",width=800,height=500)

# %%
Image("coin_11.png",width=800,height=500)
