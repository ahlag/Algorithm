# %%
from IPython.display import Image, Video
Image("pascal_1.png",width=700,height=500)

# %%
Image("pascal.gif",width=300,height=500)

# %%
Image("pascal_2.png",width=700,height=500)

# %%
Image("pascal_3.png",width=700,height=500)

# %%
Image("pascal_4.png",width=700,height=500)

# %%
Image("pascal_5.png",width=700,height=500)

# %%
Image("pascal_6.png",width=700,height=500)

# %%
Image("pascal_7.png",width=700,height=500)

# %%
Image("pascal_8.png",width=700,height=500)

# %%
Image("pascal_9.png",width=700,height=500)

# %%
Image("pascal_10.png",width=700,height=500)

# %%
Video("pascal.mov",width=700,height=500)
# Out:
# <video src="pascal.mov" controls  width="700"  height="500">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Image("pascal_11.png",width=700,height=500)

# %%
Image("pascal_12.png",width=700,height=500)

# %%
class Solution:
    def getRow(self, rowIndex: int):
        
        row = []
            
        for i in range(rowIndex+1):
            tmp = []
            for j in range(i+1):
                if j == 0 or i == j:
                    tmp.append(1)
                else:
                    tmp.append(row[i-1][j-1] + row[i-1][j])
                # print(i, j)
            row.append(tmp)
            
        return row[rowIndex]

# %% [markdown]
# ## Personal

# %%
class Solution:
    def getRow(self, rowIndex: int):
        
        triangle = [ [1]*(i+1) for i in range(rowIndex+1) ]
        
        for i in range(2, rowIndex+1):
            for j in range(1,i):
                triangle[i][j] = triangle[i-1][j-1] + triangle[i-1][j]

        return triangle[rowIndex]

# %%
Image("pascal_13.png",width=700,height=500)

# %%
Image("pascal_14.png",width=700,height=500)

# %%
Image("pascal_15.png",width=700,height=500)
