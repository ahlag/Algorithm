# %%
from IPython.display import Image, Video
Image("bfs_1.png",width=900,height=500)

# %%
Video("bfs_1.mov",width=600,height=300)
# Out:
# <video src="bfs_1.mov" controls  width="600"  height="300">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Image("bfs_2.png",width=900,height=500)

# %%
Image("bfs_3.png",width=900,height=500)

# %%
Image("bfs_4.png",width=900,height=500)

# %%
Image("bfs_5.png",width=900,height=500)

# %%
class Solution:
    def levelOrder(self, root):
        """
        :type root: TreeNode
        :rtype: List[List[int]]
        """
        levels = []
        if not root:
            return levels
        
        def helper(node, level):
            # start the current level
            if len(levels) == level:
                levels.append([])

            # append the current node value
            levels[level].append(node.val)

            # process child nodes for the next level
            if node.left:
                helper(node.left, level + 1)
            if node.right:
                helper(node.right, level + 1)
            
        helper(root, 0)
        return levels

# %%
Image("bfs_6.png",width=900,height=500)

# %%
Image("bfs_7.png",width=900,height=500)

# %%
from collections import deque
class Solution:
    def levelOrder(self, root):
        """
        :type root: TreeNode
        :rtype: List[List[int]]
        """
        levels = []
        if not root:
            return levels
        
        level = 0
        queue = deque([root,])
        while queue:
            # start the current level
            levels.append([])
            # number of elements in the current level 
            level_length = len(queue)
            
            for i in range(level_length):
                node = queue.popleft()
                # fulfill the current level
                levels[level].append(node.val)
                
                # add child nodes of the current level
                # in the queue for the next level
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            
            # go to next level
            level += 1
        
        return levels

# %%
Image("bfs_8.png",width=900,height=500)

# %%
Video("bfs_2.mov",width=600,height=300)
# Out:
# <video src="bfs_2.mov" controls  width="600"  height="300">
#       Your browser does not support the <code>video</code> element.
#     </video>
