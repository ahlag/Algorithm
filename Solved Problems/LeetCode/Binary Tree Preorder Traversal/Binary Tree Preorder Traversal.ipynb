# %% [markdown]
# https://leetcode.com/explore/learn/card/data-structure-tree/134/traverse-a-tree/928/

# %%
from IPython.display import Image, Video
Image("tree_1.png",width=700,height=500)

# %%
Image("tree_13.png",width=700,height=500)

# %%
Image("tree_2.png",width=700,height=500)

# %%
class TreeNode(object):
    """ Definition of a binary tree node."""
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

# %%
Image("tree_3.png",width=700,height=500)

# %%
class Solution(object):
    def preorderTraversal(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        if root is None:
            return []
        
        stack, output = [root, ], []
        
        while stack:
            root = stack.pop()
            if root is not None:
                output.append(root.val)
                if root.right is not None:
                    stack.append(root.right)
                if root.left is not None:
                    stack.append(root.left)
        
        return output

# %%
Image("tree_4.png",width=700,height=500)

# %%
Image("tree_5.png",width=700,height=500)

# %% [markdown]
# https://www.sciencedirect.com/science/article/pii/0020019079900681

# %%
Video("morris.mov",width=600,height=500)
# Out:
# <video src="morris.mov" controls  width="600"  height="500">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
class Solution(object):
    def preorderTraversal(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        node, output = root, []
        while node:  
            if not node.left: 
                output.append(node.val)
                node = node.right 
            else: 
                predecessor = node.left 

                while predecessor.right and predecessor.right is not node: 
                    predecessor = predecessor.right 

                if not predecessor.right:
                    output.append(node.val)
                    predecessor.right = node  
                    node = node.left  
                else:
                    predecessor.right = None
                    node = node.right         

        return output

# %%
Image("tree_6.png",width=700,height=500)

# %%
Image("tree_7.png",width=700,height=500)

# %%
Image("tree_8.png",width=700,height=500)

# %%
Video("pre-order.mov",width=400,height=300)
# Out:
# <video src="pre-order.mov" controls  width="400"  height="300">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Image("tree_9.png",width=700,height=500)

# %%
Video("in-order.mov",width=400,height=300)
# Out:
# <video src="in-order.mov" controls  width="400"  height="300">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Image("tree_10.png",width=700,height=500)

# %%
Image("tree_11.png",width=700,height=500)

# %%
Video("post-order.mov",width=400,height=300)
# Out:
# <video src="post-order.mov" controls  width="400"  height="300">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Image("tree_12.png",width=700,height=500)

# %% [markdown]
# ## Iterative
#
# Explanation <br>
# https://leetcode.com/problems/binary-tree-inorder-traversal/discuss/713539/Python-3-All-Iterative-Traversals-InOrder-PreOrder-PostOrder-Similar-Solutions

# %%
class Solution:
    def preorderTraversal(self, root):
        res, stack = [], [(root, False)]
        while stack:
            node, visited = stack.pop()  # the last element
            if node:
                if visited:  
                    res.append(node.val)
                else:  # preorder: root -> left -> right
                    stack.append((node.right, False))
                    stack.append((node.left, False))
                    stack.append((node, True))
        return res

# %% [markdown]
# ## Recursive
#
# Explanation <br>
# https://leetcode.com/problems/binary-tree-inorder-traversal/discuss/546002/Easy-to-understand-or-Iterative-and-Recursive-or-Faster-or-Simple-or-Python-Solution

# %%
class Solution:
    def preorderTraversal(self, root):
        
        output = []
        
        def helper(node):
            
            if node:
                output.append(node.val)
                helper(node.left)
                helper(node.right)
        
        
        helper(root)
        
        return output

# %%
class Solution:
    def preorderTraversal(self, root):
        
        return self.helper(root, [])
    
    def helper(self, node, output):
        
        if node:
            output.append(node.val)
            self.helper(node.left, output)
            self.helper(node.right, output)
        
        return output
