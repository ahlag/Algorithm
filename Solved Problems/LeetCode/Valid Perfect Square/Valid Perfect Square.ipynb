# %%
from IPython.display import Image
Image("square_1.png",width=900,height=500)

# %%
Image("square_2.png",width=900,height=500)

# %%
Image("square_3.png",width=900,height=500)

# %%
Image("square_4.png",width=900,height=500)

# %%
Image("square_5.png",width=900,height=500)

# %%
Image("square_6.png",width=900,height=500)

# %%
Image("square_7.png",width=900,height=500)

# %%
Image("square_8.png",width=900,height=500)

# %%
Image("square_9.png",width=900,height=500)

# %%
Image("square_10.png",width=900,height=500)
